# %% [markdown]
# # Hull Refactored Workflow
#
# This notebook runs the refactored pipeline: feature engineering → training → prediction → submission.

# %%
from hullpred.pipeline import train_pipeline, predict_pipeline, submit_pipeline

config_path = None  # or set to 'configs/default.yaml'

# %%
train_result = train_pipeline(config_path)
train_result["overall"]

# %%
pred_df = predict_pipeline(config_path)
pred_df.head()

# %%
submission_path = submit_pipeline(config_path)
submission_path

# %% [markdown]
# Artifacts are saved under the artifacts/ directory (models, features, oof, preds, reports, submission).
